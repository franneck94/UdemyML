# %% [markdown]
# ### Dataset

# %%
import numpy as np
np.random.seed(42)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(n_samples=100, centers=1, n_features=2)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
plt.scatter(x_test[:, 0], x_test[:, 1])
plt.show()

print(f"Min: {np.min(x_test, axis=0)}")
print(f"Max: {np.max(x_test, axis=0)}")
print(f"Mean: {np.mean(x_test, axis=0)}")
print(f"Std: {np.std(x_test, axis=0)}")
# Out:
# Min: [-4.42796884  7.054616  ]
# Max: [-0.62301172 11.47752824]
# Mean: [-2.58914227  9.07620773]
# Std: [0.91326703 1.00416256]
