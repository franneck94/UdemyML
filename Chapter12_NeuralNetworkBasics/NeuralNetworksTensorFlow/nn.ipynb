# %%
from keras.models import *
from keras.layers.core import *
from keras.optimizers import *
import numpy as np
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
x = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([[0], [1], [1], [0]])

# %%
model = Sequential() # 2 Input Neuronen
model.add(Dense(8, input_dim=2)) # 8 Neuronen im nächsten Layer, (Hidden Layer 1)
model.add(Activation("tanh")) # [-1, +1]
model.add(Dense(1)) # Output Layer
model.add(Activation("sigmoid")) # [0, 1]

# %%
sgd = SGD(lr=0.1)
model.compile(loss="binary_crossentropy", optimizer=sgd, metrics=["accuracy"])
model.fit(x, y, nb_epoch=200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0296 - acc: 1.0000
# Epoch 2/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0295 - acc: 1.0000
# Epoch 3/200
# 4/4 [==============================] - 0s 0us/step - loss: 0.0295 - acc: 1.0000
# Epoch 4/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0294 - acc: 1.0000
# Epoch 5/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0294 - acc: 1.0000
# Epoch 6/200
# 4/4 [==============================] - 0s 250us/step - loss: 0.0293 - acc: 1.0000
# Epoch 7/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0293 - acc: 1.0000
# Epoch 8/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0293 - acc: 1.0000
# Epoch 9/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0292 - acc: 1.0000
# Epoch 10/200
# 4/4 [==============================] - 0s 249us/step - loss: 0.0292 - acc: 1.0000
# Epoch 11/200
# ...

# %%
preds = [model.predict(x_p) for x_p in x]
print(preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9cd84dd055c5> in <module>()
# ----> 1 preds = [model.predict(x_p) for x_p in x]
#       2 print(preds)
#
# <ipython-input-13-9cd84dd055c5> in <listcomp>(.0)
# ----> 1 preds = [model.predict(x_p) for x_p in x]
#       2 print(preds)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1145                              'argument.')
#    1146         # Validate user data.
# -> 1147         x, _, _ = self._standardize_user_data(x)
#    1148         if self.stateful:
#    1149             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
# ...
