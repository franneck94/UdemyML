# %%
import numpy as np

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.utils import *

# %%
# XOR Dataset: 
# A, B sind binäre Werte {0, 1}
# XOR(A, B) = A ^ B
def XOR(A, B):
    if (A == 1 and B == 0) or (A == 0 and B == 1):
        return 1
    else:
        return 0

# %%
x = np.array([[0,0], [0,1], [1,0], [1,1]], dtype=np.float32)
y = np.array([[0], [1], [1], [0]], dtype=np.float32)

# %%
model = Sequential()
# Input to first Hidden Layer
model.add(Dense(8, input_dim=x.shape[1])) # Input Layer -> 1. Hidden Layer: 2x8 Weights and 8 biases
model.add(Activation("tanh")) # (-1, +1)
# Hidden to Hidden Layer
model.add(Dense(4))
model.add(Activation("tanh")) # (-1, +1)
# Output Layer
model.add(Dense(y.shape[1]))
model.add(Activation("sigmoid")) # (0, 1): value > 0.5 => class 1, else class 0
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 8)                 24
# _________________________________________________________________
# activation_2 (Activation)    (None, 8)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 36
# _________________________________________________________________
# activation_3 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# ...
# Total params: 65
# Trainable params: 65
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = SGD(lr=0.1)
model.compile(loss="binary_crossentropy", optimizer=sgd, metrics=["accuracy"])
model.fit(x, y, epochs=200)
# Out:
# Train on 4 samples
# Epoch 1/200
# 4/4 [==============================] - 0s 63ms/sample - loss: 0.6817 - accuracy: 0.7500
# Epoch 2/200
# 4/4 [==============================] - 0s 250us/sample - loss: 0.6798 - accuracy: 0.7500
# Epoch 3/200
# 4/4 [==============================] - 0s 243us/sample - loss: 0.6780 - accuracy: 0.7500
# Epoch 4/200
# 4/4 [==============================] - 0s 249us/sample - loss: 0.6764 - accuracy: 0.7500
# Epoch 5/200
# 4/4 [==============================] - 0s 499us/sample - loss: 0.6749 - accuracy: 0.7500
# Epoch 6/200
# 4/4 [==============================] - 0s 256us/sample - loss: 0.6735 - accuracy: 0.7500
# Epoch 7/200
# 4/4 [==============================] - 0s 249us/sample - loss: 0.6721 - accuracy: 0.7500
# Epoch 8/200
# 4/4 [==============================] - 0s 499us/sample - loss: 0.6708 - accuracy: 0.7500
# Epoch 9/200
# 4/4 [==============================] - 0s 256us/sample - loss: 0.6695 - accuracy: 0.7500
# Epoch 10/200
# ...

# %%
y_pred = (model.predict(x) > 0.5)
print(y_pred)
# Out:
# [[False]
#  [ True]
#  [ True]
#  [False]]
